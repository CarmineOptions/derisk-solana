# %%
import base64
import based58
import sys
import json
import os
import time
from pathlib import Path

import solana.rpc.api
from solders.signature import Signature
from solana.exceptions import SolanaRpcException
from solders.rpc.responses import GetTransactionResp

from src.parser import MarginfiTransactionParser


# %load_ext autoreload
# %autoreload 2
sys.path.append('..')


ppk = "MFv2hWf31Z9kbCa1snEPYctwafyhdvnV7FZnsebVacA"
idl_path = '../marginfi_idl2.json'


def get_tx(tx_signature):
    try:
        transaction = solana_client.get_transaction(
            tx_signature.signature, 
#             Signature.from_string(
#                 "4if5hzfKbJSxbA13ReBca2sY6kbAias7FseHG1QdUCHqSjhG4eNbGoz96TbBSNmCGoSQfKWx5gMtDVgxNb1iUV2M"
#             ),
            'jsonParsed', 
            max_supported_transaction_version=0
        )
        return transaction
    except SolanaRpcException as e:
        print(f"SolanaRpcException while fetching {str(tx_signature.signature)}")
        time.sleep(0.5)
        return get_tx(tx_signature)

    
def tx_printout(tx_parsed):

    
    print('===========logs============')
    for log, value in tx_parsed['logs'].items():
        print(f"{log} \n")
        print(f'      Parsed: {value} \n')
    
    print('=========relevant instructions=========')
    for program_id, instruction_data in tx_parsed['instructons']:
        print(f"Program ID: {program_id} \n   {instruction_data}")
    
    print('============Account Balances==========')
    for i in tx_parsed['account_balances']:
        print(i)
        
    print('============Token Balances==========')
    for i in tx_parsed['token_balances']:
        print(f"{i} \n")

# %% [markdown]
# # Parse single TX

# %%
solana_client = solana.rpc.api.Client(os.getenv("RPC_URL"))

tx_decoder = MarginfiTransactionParser(
    idl_path,  # mf ild
    solana.rpc.api.Pubkey.from_string(ppk)  # margin fi
)

transaction = solana_client.get_transaction(
    Signature.from_string(
        '64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB'
    ), 
    'jsonParsed', 
    max_supported_transaction_version=0
)

# %%
## Parser set to printing decoded tx to console (for debug perposes)
# print(tx_decoder._processor)

tx_decoder.decode_tx(transaction.value.transaction)
# Out:
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=15232047,
#    amount_decimal=6,
#    account='73iDDwiYTz1PTzyWN23w3r3rb2hMUffkZtkVJWVJ9W4P',
#    signer='BXHWiKgXouLRRjKaQ1fQrL1Lb2nuqqYM82tFfAzfNGFs',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-15232047,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=77902579,
#    amount_decimal=9,
#    account='73iDDwiYTz1PTzyWN23w3r3rb2hMUffkZtkVJWVJ9W4P',
#    signer='BXHWiKgXouLRRjKaQ1fQrL1Lb2nuqqYM82tFfAzfNGFs',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=-75905076,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_withdraw',
#    event_name='LendingAccountWithdrawEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-15232047,
#    amount_decimal=6,
#    account='73iDDwiYTz1PTzyWN23w3r3rb2hMUffkZtkVJWVJ9W4P',
#    signer='BXHWiKgXouLRRjKaQ1fQrL1Lb2nuqqYM82tFfAzfNGFs',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='64dt9xEoEkrS5ML3Bo5xhpLpJLz7L1BoDJPwTK5XFwbzswtYusiTSgHv1d2rH2o8ao2UzJgVpjgxTHhTuV834iB',
#
#    instruction_name='lending_account_repay',
#    event_name='LendingAccountRepayEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=-77902579,
#    amount_decimal=9,
#    account='73iDDwiYTz1PTzyWN23w3r3rb2hMUffkZtkVJWVJ9W4P',
#    signer='BXHWiKgXouLRRjKaQ1fQrL1Lb2nuqqYM82tFfAzfNGFs',
#    created_at=None,
#    lending_account_id=None)>

# %% [markdown]
# ## Parse transactions from oldest to newest
# - limited to one signer/ one mf account.  - '3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1'

# %%
# collect signatures related to marginfi account:
mf_account = solana.rpc.api.Pubkey.from_string("3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1")
mfacc_tx_sinatures = solana_client.get_signatures_for_address(
    mf_account,
    limit = 1000
)
print(f"Transactions to collect: {len(mfacc_tx_sinatures.value)}")
# collect mf account related txs
mfacc_txs = list()

for idx, tx in enumerate(mfacc_tx_sinatures.value):
#     print(idx+1)
    signature = tx.signature
    transaction = get_tx(tx)
    mfacc_txs.append(transaction)
print(f"Collected: {len(mfacc_txs)}")
# Out:
# Transactions to collect: 458
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 for idx, tx in enumerate(mfacc_tx_sinatures.value):
#      12 #     print(idx+1)
#      13     signature = tx.signature
# ---> 14     transaction = get_tx(tx)
#      15     mfacc_txs.append(transaction)
#      16 print(f"Collected: {len(mfacc_txs)}")
#
# Cell In[1], line 28, in get_tx(tx_signature)
#      26 def get_tx(tx_signature):
#      27     try:
# ---> 28         transaction = solana_client.get_transaction(
#      29             tx_signature.signature,
#      30 #             Signature.from_string(
#      31 #                 "4if5hzfKbJSxbA13ReBca2sY6kbAias7FseHG1QdUCHqSjhG4eNbGoz96TbBSNmCGoSQfKWx5gMtDVgxNb1iUV2M"
#      32 #             ),
#      33             'jsonParsed',
#      34             max_supported_transaction_version=0
#      35         )
#      36         return transaction
#      37     except SolanaRpcException as e:
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/solana/rpc/api.py:389, in Client.get_transaction(self, tx_sig, encoding, commitment, max_supported_transaction_version)
#     369 """Returns transaction details for a confirmed transaction.
#     370
#     371 Args:
#    (...)
#     386     1234
#     387 """  # noqa: E501 # pylint: disable=line-too-long
#     388 body = self._get_transaction_body(tx_sig, encoding, commitment, max_supported_transaction_version)
# --> 389 return self._provider.make_request(body, GetTransactionResp)
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/solana/exceptions.py:43, in handle_exceptions.<locals>.func_decorator.<locals>.argument_decorator(*args, **kwargs)
#      41 def argument_decorator(*args, **kwargs):
#      42     try:
# ---> 43         return func(*args, **kwargs)
#      44     except exception_types_caught as exc:
#      45         raise internal_exception_cls(exc, func, *args, **kwargs) from exc
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/solana/rpc/providers/http.py:48, in HTTPProvider.make_request(self, body, parser)
#      45 @handle_exceptions(SolanaRpcException, httpx.HTTPError)
#      46 def make_request(self, body: Body, parser: Type[T]) -> T:
#      47     """Make an HTTP request to an http rpc endpoint."""
# ---> 48     raw = self.make_request_unparsed(body)
#      49     return _parse_raw(raw, parser=parser)
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/solana/rpc/providers/http.py:54, in HTTPProvider.make_request_unparsed(self, body)
#      52 """Make an async HTTP request to an http rpc endpoint."""
#      53 request_kwargs = self._before_request(body=body)
# ---> 54 raw_response = httpx.post(**request_kwargs)
#      55 return _after_request_unparsed(raw_response)
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_api.py:304, in post(url, content, data, files, json, params, headers, cookies, auth, proxies, follow_redirects, cert, verify, timeout, trust_env)
#     281 def post(
#     282     url: URLTypes,
#     283     *,
#    (...)
#     297     trust_env: bool = True,
#     298 ) -> Response:
#     299     """
#     300     Sends a `POST` request.
#     301
#     302     **Parameters**: See `httpx.request`.
#     303     """
# --> 304     return request(
#     305         "POST",
#     306         url,
#     307         content=content,
#     308         data=data,
#     309         files=files,
#     310         json=json,
#     311         params=params,
#     312         headers=headers,
#     313         cookies=cookies,
#     314         auth=auth,
#     315         proxies=proxies,
#     316         follow_redirects=follow_redirects,
#     317         cert=cert,
#     318         verify=verify,
#     319         timeout=timeout,
#     320         trust_env=trust_env,
#     321     )
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_api.py:100, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxies, timeout, follow_redirects, verify, cert, trust_env)
#      42 """
#      43 Sends an HTTP request.
#      44
#    (...)
#      90 ```
#      91 """
#      92 with Client(
#      93     cookies=cookies,
#      94     proxies=proxies,
#    (...)
#      98     trust_env=trust_env,
#      99 ) as client:
# --> 100     return client.request(
#     101         method=method,
#     102         url=url,
#     103         content=content,
#     104         data=data,
#     105         files=files,
#     106         json=json,
#     107         params=params,
#     108         headers=headers,
#     109         auth=auth,
#     110         follow_redirects=follow_redirects,
#     111     )
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_client.py:821, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     806     warnings.warn(message, DeprecationWarning)
#     808 request = self.build_request(
#     809     method=method,
#     810     url=url,
#    (...)
#     819     extensions=extensions,
#     820 )
# --> 821 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_client.py:908, in Client.send(self, request, stream, auth, follow_redirects)
#     900 follow_redirects = (
#     901     self.follow_redirects
#     902     if isinstance(follow_redirects, UseClientDefault)
#     903     else follow_redirects
#     904 )
#     906 auth = self._build_request_auth(request, auth)
# --> 908 response = self._send_handling_auth(
#     909     request,
#     910     auth=auth,
#     911     follow_redirects=follow_redirects,
#     912     history=[],
#     913 )
#     914 try:
#     915     if not stream:
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_client.py:936, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     933 request = next(auth_flow)
#     935 while True:
# --> 936     response = self._send_handling_redirects(
#     937         request,
#     938         follow_redirects=follow_redirects,
#     939         history=history,
#     940     )
#     941     try:
#     942         try:
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_client.py:973, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     970 for hook in self._event_hooks["request"]:
#     971     hook(request)
# --> 973 response = self._send_single_request(request)
#     974 try:
#     975     for hook in self._event_hooks["response"]:
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_client.py:1009, in Client._send_single_request(self, request)
#    1004     raise RuntimeError(
#    1005         "Attempted to send an async request with a sync Client instance."
#    1006     )
#    1008 with request_context(request=request):
# -> 1009     response = transport.handle_request(request)
#    1011 assert isinstance(response.stream, SyncByteStream)
#    1013 response.request = request
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpx/_transports/default.py:218, in HTTPTransport.handle_request(self, request)
#     205 req = httpcore.Request(
#     206     method=request.method,
#     207     url=httpcore.URL(
#    (...)
#     215     extensions=request.extensions,
#     216 )
#     217 with map_httpcore_exceptions():
# --> 218     resp = self._pool.handle_request(req)
#     220 assert isinstance(resp.stream, typing.Iterable)
#     222 return Response(
#     223     status_code=resp.status,
#     224     headers=resp.headers,
#     225     stream=ResponseStream(resp.stream),
#     226     extensions=resp.extensions,
#     227 )
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:253, in ConnectionPool.handle_request(self, request)
#     251 except BaseException as exc:
#     252     self.response_closed(status)
# --> 253     raise exc
#     254 else:
#     255     break
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:237, in ConnectionPool.handle_request(self, request)
#     234         raise exc
#     236 try:
# --> 237     response = connection.handle_request(request)
#     238 except ConnectionNotAvailable:
#     239     # The ConnectionNotAvailable exception is a special case, that
#     240     # indicates we need to retry the request on a new connection.
#    (...)
#     244     # might end up as an HTTP/2 connection, but which actually ends
#     245     # up as HTTP/1.1.
#     246     with self._pool_lock:
#     247         # Maintain our position in the request queue, but reset the
#     248         # status so that the request becomes queued again.
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/connection.py:90, in HTTPConnection.handle_request(self, request)
#      87     elif not self._connection.is_available():
#      88         raise ConnectionNotAvailable()
# ---> 90 return self._connection.handle_request(request)
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/http11.py:112, in HTTP11Connection.handle_request(self, request)
#     110 with Trace("http11.response_closed", request) as trace:
#     111     self._response_closed()
# --> 112 raise exc
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/http11.py:91, in HTTP11Connection.handle_request(self, request)
#      82     self._send_request_body(**kwargs)
#      83 with Trace(
#      84     "http11.receive_response_headers", request, kwargs
#      85 ) as trace:
#      86     (
#      87         http_version,
#      88         status,
#      89         reason_phrase,
#      90         headers,
# ---> 91     ) = self._receive_response_headers(**kwargs)
#      92     trace.return_value = (
#      93         http_version,
#      94         status,
#      95         reason_phrase,
#      96         headers,
#      97     )
#      99 return Response(
#     100     status=status,
#     101     headers=headers,
#    (...)
#     107     },
#     108 )
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/http11.py:155, in HTTP11Connection._receive_response_headers(self, request)
#     152 timeout = timeouts.get("read", None)
#     154 while True:
# --> 155     event = self._receive_event(timeout=timeout)
#     156     if isinstance(event, h11.Response):
#     157         break
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/_sync/http11.py:191, in HTTP11Connection._receive_event(self, timeout)
#     188     event = self._h11_state.next_event()
#     190 if event is h11.NEED_DATA:
# --> 191     data = self._network_stream.read(
#     192         self.READ_NUM_BYTES, timeout=timeout
#     193     )
#     195     # If we feed this case through h11 we'll raise an exception like:
#     196     #
#     197     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     201     # perspective. Instead we handle this case distinctly and treat
#     202     # it as a ConnectError.
#     203     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.virtualenvs/derisk-solana/lib/python3.10/site-packages/httpcore/backends/sync.py:28, in SyncStream.read(self, max_bytes, timeout)
#      26 with map_exceptions(exc_map):
#      27     self._sock.settimeout(timeout)
# ---> 28     return self._sock.recv(max_bytes)
#
# File /usr/local/lib/python3.10/ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File /usr/local/lib/python3.10/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
def dump_json_to_file(json_data, file_path):
    with open(file_path, 'w') as file:
        json.dump(json_data, file, indent=4)

def load_json_from_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)


# path = './mf_txs/'
# for num, tx in enumerate(mfacc_txs):
#     dump_json_to_file(tx.to_json(), os.path.join(path, f"{'{:03d}'.format(num)}.json"))

# %% [markdown]
# #### GET data ffrom local storage:

# %%
# mfacc_txs = []
# for file_name in sorted(os.listdir('./mf_txs/')):
#     tx_json = load_json_from_file(os.path.join('./mf_txs/', file_name))
#     tx = GetTransactionResp.from_json(tx_json)
#     mfacc_txs.append(tx)
# mfacc_txs.reverse()
# print(len(mfacc_txs))
# Out:
# 429

# %%
for tx in mfacc_txs:
    print(f"=====================  Transaction: {tx.value.transaction.transaction.signatures[0]} \n")
    tx_decoder.decode_tx(tx.value.transaction)
    
# print(f"Events collected: {len(tx_decoder.events)}")
# Out:
# =====================  Transaction: 2nSZ3J63grj5qisbFtCcDr6K46hLmzcL4WtVKVYLYofDT2C6QK1j69AZxChCUs8EDDvzbZhuMDzBjY7fdLgkUSoG
#
# <LendingAccounts(
#    id=None,
#    authority='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    address='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    group='4qp6Fx6tnZkY5Wropq9wUYgtFxXKwE6viZxFHg3rdAG8',
#    created_at=None)>
# =====================  Transaction: 2WMjce2dMe2Lm7AXpQaAMrT9qtEfveTeNiSFZqXRkELmT8QhVGcmu8ir7VHcd63BBdaW9GUgqyBCJHubfNNWkynL
#
# <ParsedTransactions(
#    id=None,
#    transaction_id
# =====================  Transaction: 2974PRCyGM5kq3xzM8cwrvB2T7UC4VkE9Fmycc3QYU7TW2JxLkDR6L1smqKuETBDdRPNnq7KE13RDTHAiYWKMyC6
#
# =====================  Transaction: 4G1dgy9FhpQ7b7fst4Ptf8HSBqMn4hjDTwRLa94aJeHiUV4TF33c6V4KRtmnoYkshUuDfMSJSswWhg9RC9a2dJDP
#
# =====================  Transaction: 4mfvf9pnyAo2mK1umrWppJt3Tt8PbQCtpN6rZMqBABnVXbcQoqsVJGAkHxRs9MAhxdc8f9KA6Y86ac2yQhk1RHpA
#
# =====================  Transaction: 2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz
#
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_deposit',
#    event_name='LendingAccountDepositEvent',
#
#    position='asset',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=382267232,
#    amount_decimal=None,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=87132224,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-87132224,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=0,
#    amount_decimal=9,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=-372465505,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='2evSJVJPmiwRQutgs9gd9yXABSnF4Jjya5R6n87ba8GhNQfLEUvFsJRsdWNSguq756ZuVuVRCNQKf7wPAa6GnzEz',
#
#    instruction_name='lending_account_withdraw',
#    event_name='LendingAccountWithdrawEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-87132224,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# =====================  Transaction: 4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF
#
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_deposit',
#    event_name='LendingAccountDepositEvent',
#
#    position='asset',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=19421340,
#    amount_decimal=None,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=4422979,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-4422979,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=0,
#    amount_decimal=9,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=-18923355,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='4pEZ4WvAer6FjCQgHGBiZJaABgG4koFXVqDLdBmbLcuddbY1is2D1eiQd95FzGX6zeHU9BVi8q2cJ3LihvQbd2RF',
#
#    instruction_name='lending_account_withdraw',
#    event_name='LendingAccountWithdrawEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-4422979,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# =====================  Transaction: 76VeJ8yvbNT3kNxRHCGQAhiwonj8V65rVYcQa5WiMXCD2Xb5pak33ZAWhD6ex5nfPTNqZHF2M5FBLCoG7y9JuaL
#
# =====================  Transaction: 3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4
#
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_deposit',
#    event_name='LendingAccountDepositEvent',
#
#    position='asset',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=354585847,
#    amount_decimal=None,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=84091392,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-84091392,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=0,
#    amount_decimal=9,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_liquidate',
#    event_name='LendingAccountLiquidateEvent',
#
#    position='liability',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=-345493898,
#    amount_decimal=6,
#    account='3pUsToJqWgT8j6zXrC5fHnD3YX987JbpV8EH2SzxV9k1',
#    signer='DAhb626CWFq7GwmPPexXBU3jXLHf8MK478tNje81trPc',
#    created_at=None,
#    lending_account_id=None)>
# <ParsedTransactions(
#    id=None,
#    transaction_id='3m8HnFPLXTShdPCSzDZxvSXRLQ2cy5g7YhhWjdMasRWmRXD5QVSnuFgpZrJCjEMvBJFZ9s3Y144x4gmG5uLwVja4',
#
#    instruction_name='lending_account_withdraw',
#    event_name='LendingAccountWithdrawEvent',
#
#    position='asset',
#    token='EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#    amount=-84091392,
#    amount_decimal=6,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# =====================  Transaction: Fbz77a8ueKeBKvqGyjntg4Q2pAmhJaxBPs6oXe9wsJFLYnGaEjMKvgEJJURHngv5KgyagwNN4pQu5D2zzzF6nCg
#
# =====================  Transaction: 3VW3GmLm75hmPMd1XqkZC4T8oY9JwCRknvznRSfR7YaX1WbZNEJmjtprMS5i9vAyjJBdM46EDv2MRf6pCVsh5EwK
#
# =====================  Transaction: 4biQMpvxi1sY89TTUhJKq3mSzFJ6BfkNGZnx1wyYmczZkA3CbKtajweUnzhMRhRMKaCno8xRgsUxuFW5UT5ZhEeC
#
# =====================  Transaction: 4HHwLjtHmkGfeS6ffGBBRSRDHaMyXbSXGSKQ1h4jPbwH9YEQZVNe9HbuMUkAxtZszA2eezQ4kJh31jmaNvtk5gtG
#
# =====================  Transaction: 2WeuXmDPGxGQ4mjfrsDQjQvDDwZ1nRypwEhuvWrepS1duy8JpoPJa71eguUdzkBLErhLE7KE2mgEBLZ6EcPdzrEJ
#
# =====================  Transaction: 66Zh29Pjs9wXueEsQKApWBDZCBjQCp8yaFzfNRDd29nb4srPcotFYWMowuR8BFwDxWhD3d26WJJxi9RP5CShCZc3
#
# =====================  Transaction: 3weiPLvDzg8Q8dT3ZepSz8Yy7kuh6USTTJscxbXGBPwroYxsWLukeXxbfcrZvjsHenWJyP2QSXgtV1PAQ5sCTipV
#
# =====================  Transaction: 2FvriuyujrKgsuk7N4bqALmSQmWSwVfxEv4ZhfSRDMyTTJeR8WiyezTiZ2xRcJC2zcjUesHAaYn9HpRbSBQ78j6e
#
# =====================  Transaction: VNrZrx82yyVLo94Q3QZFjXLq3KXuMYYY3RyAT9cqY4czTZJouzEFouhUibvpxFba9U4Sid2rxNC6CXFiRKz2CzK
#
# =====================  Transaction: 2WtrMrTprGXFREfzQv7zzr8QkduqKLgaknAtFsQvCWbeVXLWEHaq3XGJFpAY857YjCspJurUHa3Z4n9w7tjPjTZi
#
# =====================  Transaction: ztciSe9d7NNUBarJvbEUjNNBLvt1KreRy6WHF2rv87eXruN3eChbziE3GQf5NxR4RaRWYw1frwMcqG7KiF7P126
#
# =====================  Transaction: wiFRxE8znqgLD21HCYmeEj4rN9zUTt9BgjMM6SPrkULGQyBUtRH5P6uwpwNHyjwuC5b29szPPQMfd5h5m8nFjbF
#
# <ParsedTransactions(
#    id=None,
#    transaction_id='wiFRxE8znqgLD21HCYmeEj4rN9zUTt9BgjMM6SPrkULGQyBUtRH5P6uwpwNHyjwuC5b29szPPQMfd5h5m8nFjbF',
#
#    instruction_name='lending_account_deposit',
#    event_name='LendingAccountDepositEvent',
#
#    position='asset',
#    token='J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn',
#    amount=386802398,
#    amount_decimal=None,
#    account='L1QormaHsNEEhXcxn4scKGQVAwjuSznhLSUKKZh9UPf',
#    signer='LiqorS3DoM1XUTqhoTn8VpQmkLNdfq1KGBYMb5D3Ts1',
#    created_at=None,
#    lending_account_id=None)>
# =====================  Transaction: PRDQKyePZXq66oDEASxbwcYdbYUknjdCMQ7U1zQfqxrf4rg2mWPztGFLGTpe7CL3vi48T2dRqNKEJK3R7RjRE6t
#
# =====================  Transaction: 4pXKyiC2atmRK8waEYCenTMUg4HotdCt4egK94biFzGcYDedognQjUaMmi3Vfu1ZGMLax78rBv6tN1F7cC7HGRrp
#
# =====================  Transaction: 2fy3q8X9PybSpkEkBA2LeB2xJgakSnFq95AzfkNYQMn4pj9gWExH6Hsehy4z856gzq3roSNQkxvuwz19UH1YZFH2
#
# =====================  Transaction: 4fGosKCFnWPttj2A53K6MkYHyrKJU47s49By8tzek5QmyXk7xBSv4jojeiSM8221wUgv5iTwAPqRhQNLcQLntwC6

# %% [markdown]
# get data for margin fi account:
